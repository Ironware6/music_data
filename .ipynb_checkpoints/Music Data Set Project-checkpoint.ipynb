# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as stats

# %matplotlib inline

# %%
music = pd.read_csv("Hot Stuff.csv")

# %%
music
# Out:
#                                                       url      WeekID  \
# 0       http://www.billboard.com/charts/hot-100/1990-0...   2/10/1990
# 1       http://www.billboard.com/charts/hot-100/1990-0...   2/17/1990
# 2       http://www.billboard.com/charts/hot-100/1990-0...   2/24/1990
# 3       http://www.billboard.com/charts/hot-100/1990-0...    3/3/1990
# 4       http://www.billboard.com/charts/hot-100/1990-0...   3/10/1990
# 5       http://www.billboard.com/charts/hot-100/1990-0...   3/17/1990
# 6       http://www.billboard.com/charts/hot-100/1990-0...   3/24/1990
# 7       http://www.billboard.com/charts/hot-100/1990-0...   3/31/1990
# 8       http://www.billboard.com/charts/hot-100/1990-0...    4/7/1990
# 9       http://www.billboard.com/charts/hot-100/1990-0...   4/14/1990
# 10      http://www.billboard.com/charts/hot-100/1990-0...   4/21/1990
# 11      http://www.billboard.com/charts/hot-100/1990-0...   4/28/1990
# ...

# %%
music['Performer'].mode()
# Out:
# 0    Elton John
# dtype: object

# %%
music['Weeks on Chart'].max()
# Out:
# 87

# %%
music.describe()
# Out:
#        Week Position       Instance  Previous Week Position  Peak Position  \
# count  317795.000000  317795.000000           287367.000000  317795.000000
# mean       50.499287       1.064756               47.648342      41.481921
# std        28.865696       0.299354               28.065007      29.532136
# min         1.000000       1.000000                1.000000       1.000000
# 25%        25.500000       1.000000               23.000000      14.000000
# 50%        50.000000       1.000000               47.000000      39.000000
# 75%        75.000000       1.000000               72.000000      66.000000
# max       100.000000       8.000000              100.000000     100.000000
#
#        Weeks on Chart
# count   317795.000000
# mean         9.060187
# std          7.442308
# min          1.000000
# 25%          4.000000
# 50%          7.000000
# 75%         13.000000
# max         87.000000

# %%
music.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317795 entries, 0 to 317794
# Data columns (total 10 columns):
# url                       317795 non-null object
# WeekID                    317795 non-null object
# Week Position             317795 non-null int64
# Song                      317795 non-null object
# Performer                 317795 non-null object
# SongID                    317795 non-null object
# Instance                  317795 non-null int64
# Previous Week Position    287367 non-null float64
# Peak Position             317795 non-null int64
# Weeks on Chart            317795 non-null int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 24.2+ MB

# %%
music.plot(x = "Week Position" , y = "Peak Position")
plt.title("Week Position vs Peak Position")
plt.xlabel("The Week Position of the Song")
plt.ylabel("Peak Position of the Song")
# Out:
# Text(0, 0.5, 'Peak Position of the Song')

# %%
musicJane = music['Performer'] == 'Jane Child'

# %%
janedf = music[musicJane]

# %%
janedf.plot(x = "Performer", y = "Peak Position")
plt.title("Jane Child Peak Positions of Songs")
plt.xlabel("Jane Child")
plt.ylabel("Peak Position of the Songs")
# Out:
# Text(0, 0.5, 'Peak Position of the Songs')

# %%
musicDrake = music['Performer'] == 'Drake'
